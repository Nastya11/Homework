# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x,a,b,c):
    arg=(x-a)/b
    return c*np.exp(-(arg)**2)

# %%
xa, xb= -2.,2.
npts=20

# %%
xx = np.linspace(xa,xb)

# %%
np.random.seed(123)

# %%
noise=np.random.normal(loc=0, scale=0.03, size=xx.size)

# %%
a=0.5
b=1
c=2

# %%
yy = f(xx, a, b, c)

# %%
noisy_y=yy + 2*noise
# %matplotlib notebook
plt.plot(xx,yy,'--')
plt.plot(xx, noisy_y, 'o')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
from scipy.optimize import curve_fit

# %%
curve_fit(f, xx, noisy_y, [0.5,1.,0.2])
# Out:
# (array([ 0.50205256,  1.00254087,  1.99397273]),
#  array([[  1.78085775e-05,   7.03329403e-07,  -5.65818918e-07],
#         [  7.03329403e-07,   3.73700421e-05,  -3.67511370e-05],
#         [ -5.65818918e-07,  -3.67511370e-05,   1.05766541e-04]]))

# %%
def fl(x,a,b,c):
    return a*x**2+b*x+c

# %%
mask=noisy_y>0

# %%
popt, pcov = curve_fit(fl, xx[mask], np.log(noisy_y[mask]), [1.,1.,1.])

# %%
noisy_y[noisy_y > 0]
# Out:
# array([ 0.11312705,  0.01954072,  0.08931559,  0.08860495,  0.15379079,
#         0.15574293,  0.15280476,  0.07110315,  0.2012942 ,  0.21705332,
#         0.17277672,  0.40208992,  0.44149966,  0.48358108,  0.56647033,
#         0.61951737,  0.82465369,  0.97067782,  1.02887776,  1.28798326,
#         1.29174883,  1.36543089,  1.68217528,  1.71009549,  1.82475195,
#         1.85998885,  1.86875641,  2.07011485,  1.95679452,  2.07461738,
#         1.97465684,  1.83492141,  1.69534286,  1.60580141,  1.45274907,
#         1.51716065,  1.26311345,  1.18245166,  0.90009024,  0.85528849,
#         0.79149224,  0.58706097,  0.56652037,  0.34882465,  0.25316232,
#         0.29026857,  0.18804786])

# %%
# %matplotlib notebook
plt.plot(xx,fl(xx,*popt),'-')
plt.plot(xx[mask], np.log(noisy_y[mask]), 'o--')
plt.plot(xx,np.log(yy),'--')
# Out:
# <img src="data:image/png;base64,..." width="1022.222249301864">
